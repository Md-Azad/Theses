# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

dataset=pd.read_csv('drug_addiction.csv')
dataset.isnull().sum()
# Out:
# Did you influence by your friends?                              0
# Do you have any drug addict  friend?                            0
# Do you feel alone?                                              0
# Are you frustrate with you wage                                 0
# Are you even been harassed in your work place                   0
# Are you satisfied with your present job                         0
# Are you neglected by your family or relative?                   0
# Are you frustrated for your interpersonal relationship?         0
# Most of time do you suffer mental sickness?                     0
# Forth commingles is the couse of taking drugs?                  0
# Did you take drug without knowledge the side effect of drug?    0
# Poor result is the causes for taking drug?                      0
# Excessive money is the causes for taking drug?                  0
# Did you take drug for curiosity?                                0
# Did you influence by family member habit?                       0
# Are you satisfy with your family status?                        0
# Is drug give you more confidence?                               0
# Before you got addicted,did  you start with  smoking?           0
# response                                                        0
# dtype: int64

# %%
dataset.head()
# Out:
#    Did you influence by your friends?  Do you have any drug addict  friend?  \
# 0                                   1                                     1
# 1                                   0                                     0
# 2                                   1                                     1
# 3                                   1                                     1
# 4                                   1                                     1
#
#    Do you feel alone?  Are you frustrate with you wage  \
# 0                   1                                0
# 1                   1                                1
# 2                   1                                1
# 3                   1                                0
# 4                   0                                0
#
#    Are you even been harassed in your work place  \
# 0                                              0
# 1                                              1
# 2                                              1
# 3                                              0
# 4                                              0
#
#    Are you satisfied with your present job  \
# 0                                        1
# 1                                        1
# 2                                        1
# 3                                        1
# 4                                        0
#
#    Are you neglected by your family or relative?  \
# 0                                              0
# 1                                              0
# 2                                              1
# 3                                              1
# 4                                              0
#
#    Are you frustrated for your interpersonal relationship?  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  0
# 4                                                  0
#
#    Most of time do you suffer mental sickness?  \
# 0                                            1
# 1                                            1
# 2                                            1
# 3                                            0
# 4                                            0
#
#    Forth commingles is the couse of taking drugs?  \
# 0                                               0
# 1                                               0
# 2                                               1
# 3                                               1
# 4                                               1
#
#    Did you take drug without knowledge the side effect of drug?  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  0
#
#    Poor result is the causes for taking drug?  \
# 0                                           0
# 1                                           0
# 2                                           1
# 3                                           0
# 4                                           0
#
#    Excessive money is the causes for taking drug?  \
# 0                                               1
# 1                                               0
# 2                                               1
# 3                                               0
# 4                                               1
#
#    Did you take drug for curiosity?  \
# 0                                 1
# 1                                 1
# 2                                 1
# 3                                 1
# 4                                 1
#
#    Did you influence by family member habit?  \
# 0                                          0
# 1                                          1
# 2                                          1
# 3                                          0
# 4                                          0
#
#    Are you satisfy with your family status?  \
# 0                                         1
# 1                                         1
# 2                                         1
# 3                                         1
# 4                                         1
#
#    Is drug give you more confidence?  \
# 0                                  1
# 1                                  0
# 2                                  0
# 3                                  0
# 4                                  1
#
#    Before you got addicted,did  you start with  smoking?  response
# 0                                                  1             1
# 1                                                  0             1
# 2                                                  1             1
# 3                                                  1             1
# 4                                                  1             0

# %%
df.columns[-1]
# Out:
# 'response'

# %% [markdown]
# # LogisticRegression

# %%
# Load libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

df = pd.read_csv("drug_addiction.csv")

X = df[df.columns[0:18]]
Y = df[df.columns[18]]
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=0)

from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()

logregfit = logreg.fit(x_train, y_train)

logregpr = logreg.predict(x_test)

print("Accuracy:",metrics.accuracy_score(y_test, logregpr))
# Out:
# Accuracy: 0.8469387755102041
# /home/md/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
